# %% [markdown]
# # EEG Analizė: AD / FTD / Control
# Pilnas srautas: artefaktų valymas → požymiai → PCA → K-Means / GMM

# %%
import mne
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import skew, kurtosis, iqr, entropy, median_abs_deviation
from scipy.signal import find_peaks
from scipy.integrate import trapezoid

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, adjusted_rand_score, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from scipy.optimize import linear_sum_assignment

print('Bibliotekos įkeltos.')
# Out:
# Bibliotekos įkeltos.

# %%
files = glob.glob('*.set')
print('Rasta failų:', len(files))

df_meta = pd.read_csv('participants.tsv', sep='\t')
print(df_meta.head())
print('Grupės:', df_meta['Group'].value_counts().to_dict())
# Out:
# Rasta failų: 88
#   participant_id Gender  Age Group  MMSE
# 0        sub-001      F   57     A    16
# 1        sub-002      F   78     A    22
# 2        sub-003      M   70     A    14
# 3        sub-004      F   67     A    20
# 4        sub-005      M   70     A    22
# Grupės: {'A': 36, 'C': 29, 'F': 23}

# %% [markdown]
# ## 1. Artefaktų valymas

# %%
def clean_raw(raw, notch_freq=50):
    """
    Artefaktų valymo pipeline optimizuotas eyes-closed EEG.
    ICA nenaudojamas: eyes-closed duomenyse mirksėjimų minimaliai,
    nėra EOG elektrodų, ICA rizikuoja pašalinti alfa komponentus.

    Žingsniai:
      1. Bandpass filtras (1-40 Hz)
      2. Notch filtras (50 Hz)
      3. Blogų kanalų detekcija ir interpoliacija
      4. Vidutinis referencijavimas
      5. Amplitudės atmetimas (200 µV, 4 sekundžių epochos)
    """
    raw = raw.copy()

    # Žingsnis 1 & 2: Filtravimas
    raw.filter(l_freq=1.0, h_freq=40.0, method='fir', fir_window='hamming', verbose=False)
    raw.notch_filter(freqs=notch_freq, verbose=False)

    # Žingsnis 3: Blogų kanalų detekcija (variacija)
    raw.set_montage('standard_1020', on_missing='ignore', verbose=False)
    data_check = raw.get_data()
    ch_vars = np.var(data_check, axis=1)
    med_var = np.median(ch_vars)
    bad_mask = (ch_vars > 10 * med_var) | (ch_vars < 0.1 * med_var)
    bad_chs = [raw.ch_names[i] for i, b in enumerate(bad_mask) if b]

    if bad_chs:
        raw.info['bads'] = bad_chs
        raw.interpolate_bads(reset_bads=True, verbose=False)
        print(f'  Interpoliuoti blogų kanalai: {bad_chs}')
    else:
        print('  Blogų kanalų nerasta.')

    # Žingsnis 4: Vidutinis referencijavimas
    raw.set_eeg_reference('average', projection=True, verbose=False)
    raw.apply_proj(verbose=False)

    # Žingsnis 5: Amplitudės atmetimas (4 sekundžių epochos, 200 µV)
    events = mne.make_fixed_length_events(raw, duration=4.0)
    epochs = mne.Epochs(
        raw, events,
        tmin=0, tmax=4.0,
        baseline=None,
        reject={'eeg': 200e-6},
        flat={'eeg': 1e-8},
        verbose=False,
        preload=True,
    )

    if len(epochs) == 0:
        print('  ĮSPĖJIMAS: Visos epochos atmestos — atleidžiama iki 400 µV')
        epochs = mne.Epochs(raw, events, tmin=0, tmax=4.0,
                            baseline=None, reject={'eeg': 400e-6},
                            verbose=False, preload=True)

    pct_kept = len(epochs) / len(events) * 100
    print(f'  Epochos: {len(epochs)}/{len(events)}  ({pct_kept:.0f}%)')

    clean = epochs.get_data()
    clean = clean.transpose(1, 0, 2)
    clean = clean.reshape(clean.shape[0], -1)
    return clean, raw.ch_names, raw.info['sfreq']

# %% [markdown]
# ## 2. Požymių išgavimas

# %%
import numpy as np
from scipy.stats import skew, kurtosis, entropy
from scipy.signal import find_peaks
import mne
from scipy.integrate import trapezoid
from scipy.stats import median_abs_deviation, iqr


def extract_features(signal, sfreq=256):
    signal = np.asarray(signal, dtype=np.float64)

    if len(signal) < sfreq:
        return {}

    eps = 1e-10

    # -----------------------
    # BASIC STATS (minimal)
    # -----------------------
    mean_val = np.mean(signal)
    std_val = np.std(signal) + eps

    # -----------------------
    # ROBUST VARIABILITY
    # -----------------------
    skew_val = skew(signal, bias=False)
    kurt_val = kurtosis(signal, fisher=True, bias=False)

    # -----------------------
    # NONLINEAR (simple entropy)
    # -----------------------
    hist, _ = np.histogram(signal, bins=50, density=True)
    hist = hist[hist > 0]
    entropy_val = entropy(hist)

    # -----------------------
    # ZERO-CROSSINGS (kept only one)
    # -----------------------
    zero_crossings = np.sum(np.diff(np.sign(signal)) != 0)

    # -----------------------
    # PEAK ACTIVITY (optional but stable)
    # -----------------------
    peaks, _ = find_peaks(signal)
    num_peaks = len(peaks)

    # -----------------------
    # PSD (EEG core)
    # -----------------------
    psd, freqs = mne.time_frequency.psd_array_welch(
        signal[np.newaxis, :],
        sfreq=sfreq,
        fmin=1.0,
        fmax=40.0,
        n_fft=int(sfreq * 4),
        n_overlap=int(sfreq * 2),
        verbose=False,
    )

    psd = np.squeeze(psd)
    total_power = trapezoid(psd, freqs) + eps

    def band(fmin, fmax):
        idx = (freqs >= fmin) & (freqs <= fmax)
        return trapezoid(psd[idx], freqs[idx])

    delta = band(1, 4)
    theta = band(4, 8)
    alpha = band(8, 13)
    beta  = band(13, 30)

    # -----------------------
    # RELATIVE POWERS (IMPORTANT FOR CLUSTERING)
    # -----------------------
    delta_rel = delta / total_power
    theta_rel = theta / total_power
    alpha_rel = alpha / total_power
    beta_rel  = beta / total_power

    # -----------------------
    # SPECTRAL FEATURES (EEG slowing)
    # -----------------------
    cum_psd = np.cumsum(psd)

    median_freq = freqs[np.searchsorted(cum_psd, 0.5 * cum_psd[-1])]
    sef95 = freqs[np.searchsorted(cum_psd, 0.95 * cum_psd[-1])]

    # -----------------------
    # HJORTH (KEEP ONLY 2 MOST IMPORTANT)
    # -----------------------
    dx = np.diff(signal)

    activity = np.var(signal)
    mobility = np.sqrt(np.var(dx) / (activity + eps))

    ddx = np.diff(dx)
    complexity = np.sqrt(np.var(ddx) / (np.var(dx) + eps)) / (mobility + eps)

    return {
        # basic
        "mean": mean_val,
        "std": std_val,

        # shape
        "skewness": skew_val,
        "kurtosis": kurt_val,

        # complexity
        "entropy": entropy_val,
        "hjorth_mobility": mobility,
        "hjorth_complexity": complexity,

        # morphology
        "zero_crossings": zero_crossings,
        "num_peaks": num_peaks,

        # spectral (MOST IMPORTANT)
        "delta_rel": delta_rel,
        "theta_rel": theta_rel,
        "alpha_rel": alpha_rel,
        "beta_rel": beta_rel,

        # spectral shift
        "median_freq": median_freq,
        "sef95": sef95,
    }

# %% [markdown]
# ## 3. Signalų apdorojimas ir požymių išgavimas

# %%
all_features = []

for file in files:
    print(f'\nApdorojamas: {file}')
    try:
        raw = mne.io.read_raw_eeglab(file, preload=True, verbose=False)
    except Exception as e:
        print(f'  KLAIDA įkeliant: {e}')
        continue

    try:
        clean_data, ch_names, sfreq = clean_raw(raw)
    except Exception as e:
        print(f'  KLAIDA valant: {e} — praleidžiama')
        continue

    subject_row = {'file': file}
    for i, ch in enumerate(ch_names):
        feats = extract_features(clean_data[i], sfreq=sfreq)
        for k, v in feats.items():
            subject_row[f'{ch}_{k}'] = v

    all_features.append(subject_row)

df = pd.DataFrame(all_features)
print(f'\nPožymių matrica: {df.shape}')
df.to_csv('EEG_Features_fixed.csv', index=False)
print('Išsaugota į EEG_Features.csv')
# Out:
# Apdorojamas: sub-001_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 149/149  (100%)
#
# Apdorojamas: sub-002_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 196/198  (99%)
#
# Apdorojamas: sub-003_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 76/76  (100%)
#
# Apdorojamas: sub-004_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 172/176  (98%)
#
# Apdorojamas: sub-005_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 195/201  (97%)
#
# Apdorojamas: sub-006_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 158/158  (100%)
#
# Apdorojamas: sub-007_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 191/191  (100%)
#
# Apdorojamas: sub-008_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 187/198  (94%)
#
# Apdorojamas: sub-009_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 153/153  (100%)
#
# Apdorojamas: sub-010_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 320/320  (100%)
#
# Apdorojamas: sub-011_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 172/192  (90%)
#
# Apdorojamas: sub-012_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 209/220  (95%)
#
# Apdorojamas: sub-013_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 197/209  (94%)
#
# Apdorojamas: sub-014_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 219/233  (94%)
#
# Apdorojamas: sub-015_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 223/225  (99%)
#
# Apdorojamas: sub-016_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 229/243  (94%)
#
# Apdorojamas: sub-017_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 200/210  (95%)
#
# Apdorojamas: sub-018_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 209/211  (99%)
#
# Apdorojamas: sub-019_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 228/229  (100%)
#
# Apdorojamas: sub-020_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 215/217  (99%)
#
# Apdorojamas: sub-021_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 225/230  (98%)
#
# Apdorojamas: sub-022_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 191/205  (93%)
#
# Apdorojamas: sub-023_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 193/208  (93%)
#
# Apdorojamas: sub-024_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 188/189  (99%)
#
# Apdorojamas: sub-025_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 166/171  (97%)
#
# Apdorojamas: sub-026_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 181/224  (81%)
#
# Apdorojamas: sub-027_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 197/206  (96%)
#
# Apdorojamas: sub-028_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 203/204  (100%)
#
# Apdorojamas: sub-029_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 183/184  (99%)
#
# Apdorojamas: sub-030_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 119/138  (86%)
#
# Apdorojamas: sub-031_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 269/287  (94%)
#
# Apdorojamas: sub-032_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 199/199  (100%)
#
# Apdorojamas: sub-033_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 176/176  (100%)
#
# Apdorojamas: sub-034_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 237/242  (98%)
#
# Apdorojamas: sub-035_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 185/185  (100%)
#
# Apdorojamas: sub-036_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 210/210  (100%)
#
# Apdorojamas: sub-037_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 193/194  (99%)
#
# Apdorojamas: sub-038_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 217/222  (98%)
#
# Apdorojamas: sub-039_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 210/212  (99%)
#
# Apdorojamas: sub-040_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 235/241  (98%)
#
# Apdorojamas: sub-041_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 221/221  (100%)
#
# Apdorojamas: sub-042_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 232/240  (97%)
#
# Apdorojamas: sub-043_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 207/207  (100%)
#
# Apdorojamas: sub-044_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 220/220  (100%)
#
# Apdorojamas: sub-045_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 202/212  (95%)
#
# Apdorojamas: sub-046_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 177/188  (94%)
#
# Apdorojamas: sub-047_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 196/201  (98%)
#
# Apdorojamas: sub-048_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 209/247  (85%)
#
# Apdorojamas: sub-049_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 195/195  (100%)
#
# Apdorojamas: sub-050_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 198/204  (97%)
#
# Apdorojamas: sub-051_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 181/188  (96%)
#
# Apdorojamas: sub-052_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 189/190  (99%)
#
# Apdorojamas: sub-053_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 188/195  (96%)
#
# Apdorojamas: sub-054_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 208/209  (100%)
#
# Apdorojamas: sub-055_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 203/203  (100%)
#
# Apdorojamas: sub-056_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 196/197  (99%)
#
# Apdorojamas: sub-057_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 199/199  (100%)
#
# Apdorojamas: sub-058_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 187/189  (99%)
#
# Apdorojamas: sub-059_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 196/196  (100%)
#
# Apdorojamas: sub-060_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 171/187  (91%)
#
# Apdorojamas: sub-061_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 190/200  (95%)
#
# Apdorojamas: sub-062_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 220/224  (98%)
#
# Apdorojamas: sub-063_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 200/201  (100%)
#
# Apdorojamas: sub-064_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 210/212  (99%)
#
# Apdorojamas: sub-065_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 219/221  (99%)
#
# Apdorojamas: sub-066_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 136/137  (99%)
#
# Apdorojamas: sub-067_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 138/160  (86%)
#
# Apdorojamas: sub-068_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 139/143  (97%)
#
# Apdorojamas: sub-069_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 157/159  (99%)
#
# Apdorojamas: sub-070_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 119/119  (100%)
#
# Apdorojamas: sub-071_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 154/154  (100%)
#
# Apdorojamas: sub-072_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 164/164  (100%)
#
# Apdorojamas: sub-073_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 211/213  (99%)
#
# Apdorojamas: sub-074_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 237/253  (94%)
#
# Apdorojamas: sub-075_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 181/187  (97%)
#
# Apdorojamas: sub-076_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 197/204  (97%)
#
# Apdorojamas: sub-077_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 173/174  (99%)
#
# Apdorojamas: sub-078_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 210/217  (97%)
#
# Apdorojamas: sub-079_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 197/204  (97%)
#
# Apdorojamas: sub-080_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 221/228  (97%)
#
# Apdorojamas: sub-081_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 204/206  (99%)
#
# Apdorojamas: sub-082_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 189/194  (97%)
#
# Apdorojamas: sub-083_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 224/228  (98%)
#
# Apdorojamas: sub-084_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 162/163  (99%)
#
# Apdorojamas: sub-085_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 123/140  (88%)
#
# Apdorojamas: sub-086_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 20/144  (14%)
#
# Apdorojamas: sub-087_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 149/150  (99%)
#
# Apdorojamas: sub-088_task-eyesclosed_eeg.set
#   Blogų kanalų nerasta.
#   Epochos: 196/196  (100%)
#
# Požymių matrica: (88, 381)
# Išsaugota į EEG_Features.csv

# %%
# ============================================
# F ir O kanalų požymių suvidurkinimas
# ============================================
df = pd.read_csv("EEG_Features_fixed.csv")

F_channels = ['Fp1', 'Fp2', 'F3', 'F4', 'F7', 'F8', 'Fz']
O_channels = ['O1', 'O2', 'Oz']

# --------------------------------------------
# Visų požymių pavadinimai
# --------------------------------------------

features = [
    "mean",
    "std",
    "skewness",
    "kurtosis",
    "entropy",
    "hjorth_mobility",
    "hjorth_complexity",
    "zero_crossings",
    "num_peaks",
    "delta_rel",
    "theta_rel",
    "alpha_rel",
    "beta_rel",
    "median_freq",
    "sef95",
]

# ============================================
# Naujas dataframe agreguotiems požymiams
# ============================================

aggregated_df = pd.DataFrame()
aggregated_df['file'] = df['file']

# ============================================
# Skaičiuojame F ir O mean/std
# ============================================

for feat in features:

    # -------------------------
    # Frontaliniai kanalai
    # -------------------------
    F_cols = [
        f'{ch}_{feat}'
        for ch in F_channels
        if f'{ch}_{feat}' in df.columns
    ]

    if len(F_cols) > 0:
        aggregated_df[f'F_mean_{feat}'] = df[F_cols].mean(axis=1)
       # aggregated_df[f'F_std_{feat}'] = df[F_cols].std(axis=1)

    # -------------------------
    # Okcipitaliniai kanalai
    # -------------------------
    O_cols = [
        f'{ch}_{feat}'
        for ch in O_channels
        if f'{ch}_{feat}' in df.columns
    ]

    if len(O_cols) > 0:
        aggregated_df[f'O_mean_{feat}'] = df[O_cols].mean(axis=1)
        aggregated_df[f'O_std_{feat}'] = df[O_cols].std(axis=1)

    # -------------------------
    # Skirtumas O - F
    # -------------------------
    if len(F_cols) > 0 and len(O_cols) > 0:
        aggregated_df[f'DIFF_{feat}'] = (
            aggregated_df[f'O_mean_{feat}']
            - aggregated_df[f'F_mean_{feat}']
        )

# ============================================
# Rezultatas
# ============================================

print("Agreguotos matricos dydis:", aggregated_df.shape)

aggregated_df.to_csv(
    'EEG_Features_F_O_Aggregated.csv',
    index=False
)

print("Išsaugota: EEG_Features_F_O_Aggregated.csv")
# Out:
# Agreguotos matricos dydis: (88, 61)
# Išsaugota: EEG_Features_F_O_Aggregated.csv

# %% [markdown]
# ### Vizualizacija Boxplot

# %%
df = pd.read_csv("EEG_Features_F_O_Aggregated.csv")
X = df.drop(columns=["file"], errors="ignore")

df = pd.concat([df, df_meta], axis=1)
print(df.columns)

# ---------------------------
# EXISTING GROUPS
# ---------------------------
entropy_cols = [c for c in df.columns if "entropy" in c]
rms_cols = [c for c in df.columns if "rms" in c]
zc_cols = [c for c in df.columns if "zero_crossings" in c]
kurt_cols = [c for c in df.columns if "kurtosis" in c]

# ---------------------------
# NEW (IMPORTANT EEG FEATURES)
# ---------------------------
feature_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# išmetam Group jei netyčia yra
if "Group" in feature_cols:
    feature_cols.remove("Group")

# išmetam label / id jei yra
for col in ["file"]:
    if col in feature_cols:
        feature_cols.remove(col)

# ---------------------------
# 2. padarom mean per VISUS feature tipus
# ---------------------------
df["all_features_mean"] = df[feature_cols].mean(axis=1)

# ---------------------------
# 3. automatinis TOP group feature (pagal prefix)
# ---------------------------
df["entropy_mean"] = df[[c for c in feature_cols if "entropy" in c]].mean(axis=1)
df["rms_mean"] = df[[c for c in feature_cols if "rms" in c]].mean(axis=1)
df["zero_crossings_mean"] = df[[c for c in feature_cols if "zero_crossings" in c]].mean(axis=1)
df["kurtosis_mean"] = df[[c for c in feature_cols if "kurtosis" in c]].mean(axis=1)

df["alpha_mean"] = df[[c for c in feature_cols if "alpha_rel" in c]].mean(axis=1)
df["beta_mean"] = df[[c for c in feature_cols if "beta_rel" in c]].mean(axis=1)
df["theta_mean"] = df[[c for c in feature_cols if "theta_rel" in c]].mean(axis=1)
df["delta_mean"] = df[[c for c in feature_cols if "delta_rel" in c]].mean(axis=1)

df["hjorth_mobility_mean"] = df[[c for c in feature_cols if "hjorth_mobility" in c]].mean(axis=1)
df["hjorth_complexity_mean"] = df[[c for c in feature_cols if "hjorth_complexity" in c]].mean(axis=1)

df["ratio_mean"] = df[[c for c in feature_cols if "ratio" in c]].mean(axis=1)
df["freq_shift_mean"] = df[[c for c in feature_cols if ("median_freq" in c or "sef95" in c)]].mean(axis=1)

# ---------------------------
# 4. VISI POŽYMIAI PLOT'UI
# ---------------------------
features_to_plot = [
    "all_features_mean",
    "entropy_mean",
    "rms_mean",
    "zero_crossings_mean",
    "kurtosis_mean",
    "alpha_mean",
    "beta_mean",
    "theta_mean",
    "delta_mean",
    "hjorth_mobility_mean",
    "hjorth_complexity_mean",
    "ratio_mean",
    "freq_shift_mean"
]

fig, axes = plt.subplots(3, 4, figsize=(24, 12))
axes = axes.flatten()

for i, feat in enumerate(features_to_plot):
    sns.boxplot(data=df, x="Group", y=feat, ax=axes[i])
    axes[i].set_title(feat)

plt.tight_layout()
plt.show()
# Out:
# Index(['file', 'F_mean_mean', 'O_mean_mean', 'O_std_mean', 'DIFF_mean',
#        'F_mean_std', 'O_mean_std', 'O_std_std', 'DIFF_std', 'F_mean_skewness',
#        'O_mean_skewness', 'O_std_skewness', 'DIFF_skewness', 'F_mean_kurtosis',
#        'O_mean_kurtosis', 'O_std_kurtosis', 'DIFF_kurtosis', 'F_mean_entropy',
#        'O_mean_entropy', 'O_std_entropy', 'DIFF_entropy',
#        'F_mean_hjorth_mobility', 'O_mean_hjorth_mobility',
#        'O_std_hjorth_mobility', 'DIFF_hjorth_mobility',
#        'F_mean_hjorth_complexity', 'O_mean_hjorth_complexity',
#        'O_std_hjorth_complexity', 'DIFF_hjorth_complexity',
#        'F_mean_zero_crossings', 'O_mean_zero_crossings',
#        'O_std_zero_crossings', 'DIFF_zero_crossings', 'F_mean_num_peaks',
#        'O_mean_num_peaks', 'O_std_num_peaks', 'DIFF_num_peaks',
#        'F_mean_delta_rel', 'O_mean_delta_rel', 'O_std_delta_rel',
#        'DIFF_delta_rel', 'F_mean_theta_rel', 'O_mean_theta_rel',
#        'O_std_theta_rel', 'DIFF_theta_rel', 'F_mean_alpha_rel',
#        'O_mean_alpha_rel', 'O_std_alpha_rel', 'DIFF_alpha_rel',
#        'F_mean_beta_rel', 'O_mean_beta_rel', 'O_std_beta_rel', 'DIFF_beta_rel',
#        'F_mean_median_freq', 'O_mean_median_freq', 'O_std_median_freq',
#        'DIFF_median_freq', 'F_mean_sef95', 'O_mean_sef95', 'O_std_sef95',
#        'DIFF_sef95', 'participant_id', 'Gender', 'Age', 'Group', 'MMSE'],
#       dtype='str')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 76
#      72 fig, axes = plt.subplots(3, 4, figsize=(24, 12))
#      73 axes = axes.flatten()
#      74
#      75 for i, feat in enumerate(features_to_plot):
# ---> 76     sns.boxplot(data=df, x="Group", y=feat, ax=axes[i])
#      77     axes[i].set_title(feat)
#      78
#      79 plt.tight_layout()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)    697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:4485, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4483     positions = list(range(1, N + 1))
#    4484 elif len(positions) != N:
# -> 4485     raise ValueError(datashape_message.format("positions"))
#    4487 positions = np.array(positions)
#    4488 if len(positions) > 0 and not all(isinstance(p, Real) for p in positions):
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %% [markdown]
# ## 4. PCA ir dimensijų mažinimas

# %%
df = pd.read_csv('EEG_Features_F_O_Aggregated.csv')

# Tik spektriniai požymiai — kliniškai prasmingesni AD/FTD atskyrymui
spectral_cols = [c for c in df.columns if any(x in c for x in
    ['alpha', 'theta', 'delta', 'beta', 'gamma', 'ratio', 'sef95', 'median_freq',
     'hjorth_activity', 'hjorth_mobility', 'hjorth_complexity'])]
X = df[spectral_cols]
print(f'Spektrinių požymių skaičius: {X.shape[1]}')

# 1. Apkirpimas
X_clipped = np.clip(X,
    np.percentile(X, 1,  axis=0),
    np.percentile(X, 99, axis=0)
)

# 2. Skalinimas
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clipped)

# 3. Outlier pašalinimas
pca_check = PCA(n_components=10, random_state=42)
X_check   = pca_check.fit_transform(X_scaled)
distances = np.sqrt(np.sum(X_check**2, axis=1))
threshold = np.percentile(distances, 95)
mask      = distances < threshold

X_clean = X_scaled[mask]
y       = df_meta['Group'].values[mask]  # grupių etiketės su tuo pačiu mask
print(f'Pašalinta outlierių: {(~mask).sum()}, liko subjektų: {mask.sum()}')

# 4. PCA
pca   = PCA(n_components=0.95, random_state=42)
X_pca = pca.fit_transform(X_clean)
print(f'Po PCA: {X_pca.shape[1]} komponentai paaiškina 95% dispersijos')

# Scree plot
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
axes[0].bar(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
axes[0].set_xlabel('PCA komponentas'); axes[0].set_ylabel('Variacijos dalis')
axes[0].set_title('Scree plot')

axes[1].plot(np.cumsum(pca.explained_variance_ratio_))
axes[1].axhline(0.95, color='red', linestyle='--', label='95% riba')
axes[1].set_xlabel('Komponentų skaičius'); axes[1].set_ylabel('Kaupiama variacija')
axes[1].set_title('Kaupiama variacija'); axes[1].legend()
plt.tight_layout(); plt.show()

pca = PCA(n_components=0.95, random_state=42)
X_pca = pca.fit_transform(X_clean)
# Out:
# Spektrinių požymių skaičius: 32
# Pašalinta outlierių: 5, liko subjektų: 83
# Po PCA: 14 komponentai paaiškina 95% dispersijos

# %%
# =====================================
# PCA LOADINGS (INTERPRETACIJA)
# =====================================
loadings = pd.DataFrame(
    pca.components_.T,
    columns=[f'PC{i+1}' for i in range(pca.n_components_)],
    index=spectral_cols
)

print("\nPCA LOADINGS (pirmi 5 PC):")
print(loadings.iloc[:, :5])

# =====================================
# TOP FEATURES kiekvienam PC
# =====================================
n_top = 5

for pc in loadings.columns[:5]:
    print(f"\n🔥 {pc} TOP {n_top} features:")

    top_pos = loadings[pc].sort_values(ascending=False).head(n_top)
    top_neg = loadings[pc].sort_values().head(n_top)

    print("\n+ Positive loadings:")
    print(top_pos)

    print("\n- Negative loadings:")
    print(top_neg)
plt.figure(figsize=(12, 6))

sns.heatmap(
    loadings.iloc[:, :5],
    cmap="coolwarm",
    center=0
)

plt.title("PCA Loadings (spectral EEG features)")
plt.show()
# Out:
# PCA LOADINGS (pirmi 5 PC):
#                                PC1       PC2       PC3       PC4       PC5
# F_mean_hjorth_mobility    0.160181  0.138918  0.361910  0.059684 -0.105290
# O_mean_hjorth_mobility    0.300752 -0.011616  0.119723  0.263625 -0.036002
# O_std_hjorth_mobility     0.049268  0.087234 -0.001715  0.278964 -0.000199
# DIFF_hjorth_mobility      0.085999 -0.160437 -0.289033  0.161448  0.084603
# F_mean_hjorth_complexity -0.108157  0.094661  0.189337  0.021362 -0.237979
# O_mean_hjorth_complexity -0.094287  0.133949  0.134843  0.201410 -0.126462
# O_std_hjorth_complexity  -0.081977 -0.046180  0.092135  0.057774 -0.016233
# DIFF_hjorth_complexity    0.022143  0.081727 -0.106464  0.380972  0.218555
# F_mean_delta_rel         -0.242877 -0.085598  0.121865  0.130147 -0.277591
# O_mean_delta_rel         -0.263470 -0.057278  0.169277  0.082993 -0.084772
# O_std_delta_rel          -0.062042  0.022478  0.064556 -0.060179  0.191909
# DIFF_delta_rel           -0.038532  0.085171  0.118089 -0.147843  0.569056
# F_mean_theta_rel         -0.231803 -0.158269  0.203458  0.225803  0.024365
# O_mean_theta_rel         -0.204522 -0.198052  0.267804  0.181496  0.147862
# O_std_theta_rel          -0.125526 -0.174261  0.232684  0.177964  0.315728
# DIFF_theta_rel            0.062197 -0.114386  0.184166 -0.110441  0.370959
# F_mean_alpha_rel          0.248757 -0.324792  0.076781  0.114426 -0.008110
# O_mean_alpha_rel          0.292271 -0.312882  0.088834 -0.008813 -0.087414
# O_std_alpha_rel           0.151056 -0.224157  0.012917  0.126851  0.040832
# DIFF_alpha_rel            0.288440 -0.265963  0.087673 -0.099114 -0.133317
# F_mean_beta_rel           0.176498  0.134178  0.330041  0.090889 -0.102392
# O_mean_beta_rel           0.257819  0.039609  0.067865  0.253731  0.027571
# O_std_beta_rel            0.074995  0.096185  0.023243  0.260921 -0.023624
# DIFF_beta_rel             0.004457 -0.120496 -0.319735  0.097706  0.137969
# F_mean_median_freq        0.298264  0.122258  0.150717 -0.053379  0.122787
# O_mean_median_freq        0.332852 -0.016003 -0.081489 -0.046738  0.042681
# O_std_median_freq        -0.049559  0.166766 -0.037145  0.086565  0.237360
# DIFF_median_freq         -0.019435 -0.188736 -0.300156  0.019073 -0.117663
# F_mean_sef95              0.152803  0.382651  0.072998 -0.174963 -0.000333
# O_mean_sef95              0.117730  0.403183 -0.109299  0.159074  0.016772
# O_std_sef95              -0.026089  0.142407 -0.011155  0.101919 -0.092449
# DIFF_sef95               -0.016786  0.099024 -0.241507  0.433481  0.035499
#
# 🔥 PC1 TOP 5 features:
#
# + Positive loadings:
# O_mean_median_freq        0.332852
# O_mean_hjorth_mobility    0.300752
# F_mean_median_freq        0.298264
# O_mean_alpha_rel          0.292271
# DIFF_alpha_rel            0.288440
# Name: PC1, dtype: float64
#
# - Negative loadings:
# O_mean_delta_rel   -0.263470
# F_mean_delta_rel   -0.242877
# F_mean_theta_rel   -0.231803
# O_mean_theta_rel   -0.204522
# O_std_theta_rel    -0.125526
# Name: PC1, dtype: float64
#
# 🔥 PC2 TOP 5 features:
#
# + Positive loadings:
# O_mean_sef95              0.403183
# F_mean_sef95              0.382651
# O_std_median_freq         0.166766
# O_std_sef95               0.142407
# F_mean_hjorth_mobility    0.138918
# Name: PC2, dtype: float64
#
# - Negative loadings:
# F_mean_alpha_rel   -0.324792
# O_mean_alpha_rel   -0.312882
# DIFF_alpha_rel     -0.265963
# O_std_alpha_rel    -0.224157
# O_mean_theta_rel   -0.198052
# Name: PC2, dtype: float64
#
# 🔥 PC3 TOP 5 features:
#
# + Positive loadings:
# F_mean_hjorth_mobility    0.361910
# F_mean_beta_rel           0.330041
# O_mean_theta_rel          0.267804
# O_std_theta_rel           0.232684
# F_mean_theta_rel          0.203458
# Name: PC3, dtype: float64
#
# - Negative loadings:
# DIFF_beta_rel          -0.319735
# DIFF_median_freq       -0.300156
# DIFF_hjorth_mobility   -0.289033
# DIFF_sef95             -0.241507
# O_mean_sef95           -0.109299
# Name: PC3, dtype: float64
#
# 🔥 PC4 TOP 5 features:
#
# + Positive loadings:
# DIFF_sef95                0.433481
# DIFF_hjorth_complexity    0.380972
# O_std_hjorth_mobility     0.278964
# O_mean_hjorth_mobility    0.263625
# O_std_beta_rel            0.260921
# Name: PC4, dtype: float64
#
# - Negative loadings:
# F_mean_sef95      -0.174963
# DIFF_delta_rel    -0.147843
# DIFF_theta_rel    -0.110441
# DIFF_alpha_rel    -0.099114
# O_std_delta_rel   -0.060179
# Name: PC4, dtype: float64
#
# 🔥 PC5 TOP 5 features:
#
# + Positive loadings:
# DIFF_delta_rel            0.569056
# DIFF_theta_rel            0.370959
# O_std_theta_rel           0.315728
# O_std_median_freq         0.237360
# DIFF_hjorth_complexity    0.218555
# Name: PC5, dtype: float64
#
# - Negative loadings:
# F_mean_delta_rel           -0.277591
# F_mean_hjorth_complexity   -0.237979
# DIFF_alpha_rel             -0.133317
# O_mean_hjorth_complexity   -0.126462
# DIFF_median_freq           -0.117663
# Name: PC5, dtype: float64

# %% [markdown]
# ## 5. PCA vizualizacija su tikromis etiketėmis

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# 2D
for grp, color in zip(['A', 'C', 'F'], ['#F44336', '#2196F3', '#4CAF50']):
    idx = y == grp
    axes[0].scatter(X_pca[idx, 0], X_pca[idx, 1], label=grp, color=color, s=60, alpha=0.8)
axes[0].set_xlabel('PC1'); axes[0].set_ylabel('PC2')
axes[0].set_title('PCA 2D — tikros etiketės'); axes[0].legend()

# 3D
ax3d = fig.add_subplot(122, projection='3d')
for grp, color in zip(['A', 'C', 'F'], ['#F44336', '#2196F3', '#4CAF50']):
    idx = y == grp
    ax3d.scatter(X_pca[idx, 0], X_pca[idx, 1], X_pca[idx, 2],
                 label=grp, color=color, s=40, alpha=0.8)
ax3d.set_xlabel('PC1'); ax3d.set_ylabel('PC2'); ax3d.set_zlabel('PC3')
ax3d.set_title('PCA 3D — tikros etiketės'); ax3d.legend()
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 6. K-Means klasterizavimas

# %%
# Galutinis K-Means su k=3
kmeans = KMeans(n_clusters=3, n_init=50, random_state=42)
clusters_kmeans = kmeans.fit_predict(X_pca)
print('K-Means Silhouette:', silhouette_score(X_pca, clusters_kmeans))

plt.figure(figsize=(7, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters_kmeans, cmap='viridis', s=60, alpha=0.8)
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.title('K-Means klasteriai (PCA erdvė)'); plt.show()
# Out:
# K-Means Silhouette: 0.13852321018609537

# %% [markdown]
# ## 7. GMM klasterizavimas

# %%
# Geriausias covariance tipas per BIC
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(X_pca)
clusters_gmm = gmm.predict(X_pca)
print('GMM Silhouette:', silhouette_score(X_pca, clusters_gmm))
print('GMM Log-likelihood:', gmm.score(X_pca))

plt.figure(figsize=(7, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters_gmm, cmap='coolwarm', s=60, alpha=0.8)
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.title('GMM klasteriai (PCA erdvė)'); plt.show()
# Out:
# GMM Silhouette: 0.1710194933280965
# GMM Log-likelihood: -14.925048006916253

# %% [markdown]
# ### Spectral Clustering

# %%
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score

spectral = SpectralClustering(
    n_clusters=3,
    affinity="nearest_neighbors",
    random_state=42
)

clusters_spectral = spectral.fit_predict(X_pca)

plt.figure(figsize=(7,5))
plt.scatter(
    X_pca[:, 0],
    X_pca[:, 1],
    c=clusters_spectral,
    cmap="viridis",
    s=60,
    alpha=0.8
)

plt.title("Spectral Clustering (PCA space)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

print("Spectral Silhouette:", silhouette_score(X_pca, clusters_spectral))
# Out:
# Spectral Silhouette: 0.13147457370480986

# %% [markdown]
# ## 8. Įvertinimas

# %%
le = LabelEncoder()
y_enc = le.fit_transform(y)

def evaluate_clustering(y_true, clusters, name):
    cm = confusion_matrix(y_true, clusters)
    row_ind, col_ind = linear_sum_assignment(-cm)
    mapping = dict(zip(col_ind, row_ind))
    mapped  = np.array([mapping[c] for c in clusters])

    from sklearn.metrics import accuracy_score, jaccard_score
    acc = accuracy_score(y_true, mapped)
    jac = jaccard_score(y_true, mapped, average='macro')
    sil = silhouette_score(X_pca, clusters)

    print(f'\n=== {name} ===')
    print(f'Accuracy: {acc:.4f}')
    print(f'Jaccard:              {jac:.4f}')
    print(f'Silhouette:           {sil:.4f}')
    print('\nKonfuzijos matrica:')
    print(confusion_matrix(y_true, mapped))

    df_cross = pd.DataFrame({'Klasteris': clusters, 'Grupė': y})
    print('\nKlasterių sudėtis:')
    print(pd.crosstab(df_cross['Klasteris'], df_cross['Grupė']))

evaluate_clustering(y_enc, clusters_kmeans, 'K-Means')
evaluate_clustering(y_enc, clusters_gmm,    'GMM')
# Out:
# === K-Means ===
# Accuracy: 0.5422
# Jaccard:              0.3759
# Silhouette:           0.1385
#
# Konfuzijos matrica:
# [[15  6 14]
#  [ 0 19  9]
#  [ 4  5 11]]
#
# Klasterių sudėtis:
# Grupė       A   C   F
# Klasteris
# 0          15   0   4
# 1           6  19   5
# 2          14   9  11
#
# === GMM ===
# Accuracy: 0.5060
# Jaccard:              0.3111
# Silhouette:           0.1710
#
# Konfuzijos matrica:
# [[15 16  4]
#  [ 0 23  5]
#  [ 4 12  4]]
#
# Klasterių sudėtis:
# Grupė       A   C   F
# Klasteris
# 0           4   5   4
# 1          16  23  12
# 2          15   0   4

# %% [markdown]
# ### Pogrupių analizė

# %%
le = LabelEncoder()

def evaluate_clustering(y_true, clusters, X_data, name):
    cm = confusion_matrix(y_true, clusters)
    row_ind, col_ind = linear_sum_assignment(-cm)
    mapping = dict(zip(col_ind, row_ind))
    mapped  = np.array([mapping[c] for c in clusters])

    acc = accuracy_score(y_true, mapped)
    jac = jaccard_score(y_true, mapped, average='macro')
    sil = silhouette_score(X_data, clusters)

    print(f'\n=== {name} ===')
    print(f'Accuracy: {acc:.4f}')
    print(f'Jaccard: {jac:.4f}')
    print(f'Silhouette: {sil:.4f}')
    print('\nKonfuzijos matrica:')
    print(confusion_matrix(y_true, mapped))

    df_cross = pd.DataFrame({'Klasteris': clusters, 'Grupė': y_true})
    print('\nKlasterių sudėtis:')
    print(pd.crosstab(df_cross['Klasteris'], df_cross['Grupė']))

# %%
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

pairs = [
    ('A', 'C'),
    ('F', 'C'),
    ('A', 'F')
]

colors = {
    'A': '#F44336',
    'C': '#2196F3',
    'F': '#4CAF50'
}

# ============================================
# FUNKCIJA PORINEI ANALIZEI
# ============================================

def run_pair_analysis(group1, group2):

    print(f'\n==============================')
    print(f'ANALIZĖ: {group1} vs {group2}')
    print(f'==============================')

    # ----------------------------------------
    # Grupių filtravimas
    # ----------------------------------------
    mask_pair = y.isin([group1, group2])

    X_pair = X_scaled[mask][mask_pair]
    y_pair = y[mask_pair]
    
    X_pca_pair = X_pca[mask_pair]

    # ----------------------------------------
    # PCA TRUE LABELS
    # ----------------------------------------

    plt.figure(figsize=(6,5))

    for grp in [group1, group2]:
        idx = y_pair == grp

        plt.scatter(
            X_pca_pair[idx, 0],
            X_pca_pair[idx, 1],
            label=grp,
            color=colors[grp],
            s=70,
            alpha=0.85
        )

    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title(f'PCA: {group1} vs {group2}')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    # ========================================
    # KLASTERIZAVIMO METODAI
    # ========================================

    clustering_results = {}

    # ----------------------------------------
    # KMEANS
    # ----------------------------------------

    kmeans = KMeans(
        n_clusters=2,
        n_init=50,
        random_state=42
    )

    clustering_results['KMeans'] = kmeans.fit_predict(X_pca_pair)

    # ----------------------------------------
    # GMM
    # ----------------------------------------

    gmm = GaussianMixture(
        n_components=2,
        random_state=42
    )

    clustering_results['GMM'] = gmm.fit_predict(X_pca_pair)

    # ----------------------------------------
    # SPECTRAL
    # ----------------------------------------

    spectral = SpectralClustering(
        n_clusters=2,
        affinity='nearest_neighbors',
        random_state=42
    )

    clustering_results['Spectral'] = spectral.fit_predict(X_pca_pair)

    # ========================================
    # SUBPLOTS 1x3
    # ========================================

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    for ax, (name, clusters) in zip(axes, clustering_results.items()):

        scatter = ax.scatter(
            X_pca_pair[:, 0],
            X_pca_pair[:, 1],
            c=clusters,
            cmap='viridis',
            s=70,
            alpha=0.85
        )

        sil = silhouette_score(X_pca_pair, clusters)

        ax.set_title(f'{name}\nSilhouette={sil:.3f}')
        ax.set_xlabel('PC1')
        ax.set_ylabel('PC2')
        ax.grid(alpha=0.3)

    plt.suptitle(f'Klasterizacija: {group1} vs {group2}', fontsize=15)
    plt.tight_layout()
    plt.show()

    y_enc = le.fit_transform(y_pair)
    
    evaluate_clustering(y_enc, clustering_results['KMeans'], X_pca_pair, f"{group1}-{group2} KMeans")
    evaluate_clustering(y_enc, clustering_results['GMM'], X_pca_pair, f"{group1}-{group2} GMM")
    evaluate_clustering(y_enc, clustering_results['Spectral'], X_pca_pair, f"{group1}-{group2} Spectral")
# ============================================
# PALEIDIMAS VISOMS POROMS
# ============================================

for g1, g2 in pairs:
    run_pair_analysis(g1, g2)
# Out:
# ==============================
# ANALIZĖ: A vs C
# ==============================
# === A-C KMeans ===
# Accuracy: 0.7619
# Jaccard: 0.6131
# Silhouette: 0.1963
#
# Konfuzijos matrica:
# [[21 14]
#  [ 1 27]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          21   1
# 1          14  27
#
# === A-C GMM ===
# Accuracy: 0.6825
# Jaccard: 0.5060
# Silhouette: 0.2005
#
# Konfuzijos matrica:
# [[15 20]
#  [ 0 28]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          15   0
# 1          20  28
#
# === A-C Spectral ===
# Accuracy: 0.7619
# Jaccard: 0.6154
# Silhouette: 0.1709
#
# Konfuzijos matrica:
# [[24 11]
#  [ 4 24]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          24   4
# 1          11  24
#
# ==============================
# ANALIZĖ: F vs C
# ==============================
# === F-C KMeans ===
# Accuracy: 0.7083
# Jaccard: 0.5465
# Silhouette: 0.1769
#
# Konfuzijos matrica:
# [[19  9]
#  [ 5 15]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          19   5
# 1           9  15
#
# === F-C GMM ===
# Accuracy: 0.7083
# Jaccard: 0.5465
# Silhouette: 0.1769
#
# Konfuzijos matrica:
# [[19  9]
#  [ 5 15]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          19   5
# 1           9  15
#
# === F-C Spectral ===
# Accuracy: 0.6667
# Jaccard: 0.4995
# Silhouette: 0.1576
#
# Konfuzijos matrica:
# [[15 13]
#  [ 3 17]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          15   3
# 1          13  17
#
# ==============================
# ANALIZĖ: A vs F
# ==============================
# === A-F KMeans ===
# Accuracy: 0.5636
# Jaccard: 0.3804
# Silhouette: 0.1588
#
# Konfuzijos matrica:
# [[21 14]
#  [10 10]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          21  10
# 1          14  10
#
# === A-F GMM ===
# Accuracy: 0.6182
# Jaccard: 0.3968
# Silhouette: 0.1943
#
# Konfuzijos matrica:
# [[28  7]
#  [14  6]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0           7   6
# 1          28  14
#
# === A-F Spectral ===
# Accuracy: 0.5818
# Jaccard: 0.4067
# Silhouette: 0.1545
#
# Konfuzijos matrica:
# [[19 16]
#  [ 7 13]]
#
# Klasterių sudėtis:
# Grupė       0   1
# Klasteris
# 0          16  13
# 1          19   7

# %% [markdown]
# ## Dimensijų mažinimo metodų ypatumai/ palyginimas

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np

# =========================
# 1. t-SNE (ant PCA erdvės)
# =========================
tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate=200,
    random_state=42
)

X_tsne = tsne.fit_transform(X_pca)

print("t-SNE shape:", X_tsne.shape)


# =========================
# 2. Vizualizacija: PCA vs t-SNE
# =========================
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

groups = ['A', 'C', 'F']
colors = ['#F44336', '#2196F3', '#4CAF50']

# ---------------- PCA ----------------
for grp, color in zip(groups, colors):
    idx = y == grp
    axes[0].scatter(
        X_pca[idx, 0], X_pca[idx, 1],
        label=grp, color=color, s=60, alpha=0.7
    )

axes[0].set_title("PCA (2D)")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")
axes[0].legend()

# ---------------- t-SNE ----------------
for grp, color in zip(groups, colors):
    idx = y == grp
    axes[1].scatter(
        X_tsne[idx, 0], X_tsne[idx, 1],
        label=grp, color=color, s=60, alpha=0.7
    )

axes[1].set_title("t-SNE (2D)")
axes[1].set_xlabel("Dim 1")
axes[1].set_ylabel("Dim 2")
axes[1].legend()

plt.tight_layout()
plt.show()


# =========================
# 3. KMeans abiejose erdvėse
# =========================

# PCA space
kmeans_pca = KMeans(n_clusters=3, n_init=50, random_state=42)
clusters_pca = kmeans_pca.fit_predict(X_pca)

# t-SNE space
kmeans_tsne = KMeans(n_clusters=3, n_init=50, random_state=42)
clusters_tsne = kmeans_tsne.fit_predict(X_tsne)


# =========================
# 4. Clustering vizualizacija
# =========================
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

axes[0].scatter(
    X_pca[:, 0], X_pca[:, 1],
    c=clusters_pca, cmap='viridis', s=60, alpha=0.8
)
axes[0].set_title("KMeans - PCA space")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")

axes[1].scatter(
    X_tsne[:, 0], X_tsne[:, 1],
    c=clusters_tsne, cmap='viridis', s=60, alpha=0.8
)
axes[1].set_title("KMeans - t-SNE space")
axes[1].set_xlabel("Dim 1")
axes[1].set_ylabel("Dim 2")

plt.tight_layout()
plt.show()


# =========================
# 5. Silhouette palyginimas
# =========================
sil_pca = silhouette_score(X_pca, clusters_pca)
sil_tsne = silhouette_score(X_tsne, clusters_tsne)

print("\n===== Silhouette comparison =====")
print(f"PCA space:   {sil_pca:.4f}")
print(f"t-SNE space: {sil_tsne:.4f}")
# Out:
# t-SNE shape: (83, 2)
# ===== Silhouette comparison =====
# PCA space:   0.1385
# t-SNE space: 0.3778

# %%
from sklearn.metrics import confusion_matrix, silhouette_score, accuracy_score, jaccard_score
from sklearn.preprocessing import LabelEncoder
from scipy.optimize import linear_sum_assignment
import numpy as np
import pandas as pd

# =========================
# Label encoding
# =========================
le = LabelEncoder()
y_enc = le.fit_transform(y)

# =========================
# Evaluation funkcija
# =========================
def evaluate_embedding(y_true, clusters, X_embedded, name):

    # --- Confusion matrix + Hungarian matching ---
    cm = confusion_matrix(y_true, clusters)
    row_ind, col_ind = linear_sum_assignment(-cm)
    mapping = dict(zip(col_ind, row_ind))
    mapped = np.array([mapping[c] for c in clusters])

    # --- Metrics ---
    acc = accuracy_score(y_true, mapped)
    jac = jaccard_score(y_true, mapped, average='macro')
    sil = silhouette_score(X_embedded, clusters)

    print(f"\n===== {name} =====")
    print(f"Accuracy:    {acc:.4f}")
    print(f"Jaccard:     {jac:.4f}")
    print(f"Silhouette:  {sil:.4f}")

    print("\nConfusion matrix (after matching):")
    print(confusion_matrix(y_true, mapped))

    # --- Cluster composition ---
    df_cross = pd.DataFrame({
        "Cluster": clusters,
        "TrueGroup": y
    })

    print("\nCluster composition:")
    print(pd.crosstab(df_cross["Cluster"], df_cross["TrueGroup"]))


# =========================
# KMeans ant PCA
# =========================
from sklearn.cluster import KMeans

kmeans_pca = KMeans(n_clusters=3, n_init=50, random_state=42)
clusters_pca = kmeans_pca.fit_predict(X_pca)

# =========================
# KMeans ant t-SNE
# =========================
kmeans_tsne = KMeans(n_clusters=3, n_init=50, random_state=42)
clusters_tsne = kmeans_tsne.fit_predict(X_tsne)

# =========================
# EVALUATION
# =========================
evaluate_embedding(y_enc, clusters_pca, X_pca, "KMeans - PCA space")
evaluate_embedding(y_enc, clusters_tsne, X_tsne, "KMeans - t-SNE space")
# Out:
# ===== KMeans - PCA space =====
# Accuracy:    0.5422
# Jaccard:     0.3759
# Silhouette:  0.1385
#
# Confusion matrix (after matching):
# [[15  6 14]
#  [ 0 19  9]
#  [ 4  5 11]]
#
# Cluster composition:
# TrueGroup   A   C   F
# Cluster
# 0          15   0   4
# 1           6  19   5
# 2          14   9  11
#
# ===== KMeans - t-SNE space =====
# Accuracy:    0.5783
# Jaccard:     0.3977
# Silhouette:  0.3778
#
# Confusion matrix (after matching):
# [[21  7  7]
#  [ 1 19  8]
#  [ 8  4  8]]
#
# Cluster composition:
# TrueGroup   A   C  F
# Cluster
# 0          21   1  8
# 1           7  19  4
# 2           7   8  8
